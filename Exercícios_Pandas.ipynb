# %%
import pandas as pd

# %%
notas = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv')
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
notas.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
notas.shape
# Out:
# (18, 4)

# %%
notas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 578.0+ bytes

# %%
notas.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %%
notas.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
notas.dropna()
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
notas_remover = notas.query('Nome == "Alice" | Nome == "Carlos"').index
notas_remover
# Out:
# Int64Index([7, 8], dtype='int64')

# %%
notas.drop(notas_remover, axis=0, inplace=True)
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
notas.dropna(inplace=True)
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados = notas.query('Aprovado == True')
alunos_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados.replace(7.0,8.0)
alunos_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados = alunos_aprovados.replace(7.0,8.0)
alunos_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados.to_csv('alunos_aprovados.csv')

# %%
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
notas['Pontos_extras'] = notas['Notas'] * 0.40
notas
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True            3.0
# 2       Cátia     27    2.5     False            1.0
# 3       Denis     18    5.0     False            2.0
# 4        Beto     21   10.0      True            4.0
# 6        Dara     21    7.0      True            2.8
# 11       Igor     24    4.5     False            1.8
# 12  Sthefanie     26    9.5      True            3.8
# 13      Mirla     25    9.0      True            3.6
# 15     Mylena     29    7.0      True            2.8
# 17      Nadia     34    8.0      True            3.2

# %%
notas['Notas_finais'] = notas['Notas'] + notas['Pontos_extras']
notas
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20    7.5      True            3.0          10.5
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 6        Dara     21    7.0      True            2.8           9.8
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 15     Mylena     29    7.0      True            2.8           9.8
# 17      Nadia     34    8.0      True            3.2          11.2

# %%
notas['Aprovado_final'] = notas['Notas_finais'].apply(lambda x: "Sim" if x >= 6.0 else "Não")
notas
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True            3.0          10.5
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 6        Dara     21    7.0      True            2.8           9.8
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 15     Mylena     29    7.0      True            2.8           9.8
# 17      Nadia     34    8.0      True            3.2          11.2
#
#    Aprovado_final
# 0             Sim
# 2             Não
# 3             Sim
# 4             Sim
# 6             Sim
# 11            Sim
# 12            Sim
# 13            Sim
# 15            Sim
# 17            Sim

# %%
aprovados_depois = (notas['Aprovado'] == False) & (notas['Aprovado_final'] == 'Sim')
notas[aprovados_depois]
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 3   Denis     18    5.0     False            2.0           7.0            Sim
# 11   Igor     24    4.5     False            1.8           6.3            Sim
